# %% [markdown]
# # ベクトル空間の幾何学的解釈
#
# ベクトル空間を幾何学的に一言で言うと，始点が原点である有向線分（矢印）の集合です．
#
# ここでは，ベクトル空間の概念を幾何学的に図を使って解釈します．

# %% [markdown]
# ## 有向線分
#
# 有向線分とは，始点と終点との間を直線で結んだ線分で終点側に矢印をつけたものです．
# 始点を$P$として終点を$Q$としたとき，$P$から$Q$への有向線分は$\overrightarrow{PQ}$と記載します．
# したがって情報としては，始点の位置情報と終点の位置情報が必要となります．
# 下図は，有向線分の集合のイメージです．
#
# ![有向線分](./images/arrow001.jpg)

# %% [markdown]
# ## ベクトルのイメージ
#
# 無限にある有向線分の始点が原点になうように平行移動します．
# 下図がベクトル空間のイメージになります．情報量としては，有向線分の終点の位置情報だけをになります．
# 有向線分の図と比べると，統制が取れています．
#
# ![ベクトルのイメージ](./images/vector001.jpg)

# %% [markdown]
# *****
# ## ベクトルのスカラー倍
#
# ここではイメージを明確にするためにスカラーを実数$\mathbb{R}$とします．
# ベクトルにスカラーを掛ける演算は，幾何学的にはベクトルの有効成分の方向を変えずに長さをスカラー倍した有向線分にすることです．
# スカラーが負の値の場合は，有向線分の向きを逆向きにします．

# %% [markdown]
# #### ベクトルの正の実数倍
#
# ベクトルに対して，正の実数を掛けた例を示します．
# この図では，ベクトル${\bf v}$に対して，スカラーとして $2$ を掛けた例です．
# 元のベクトル${\bf v}$が青い矢印で，スカラー $2$ を掛けた$2{\bf v}$が緑色の破線の矢印となります．
# このように，矢印の方向は同じですが，線の長さが2倍になっています．
#
# ![ベクトルの2倍](./images/scalar001.jpg)
#
# この例ではスカラーが $2$ なので線分の長さが長くなっていますが，スカラーが $1$ より小さければ短くなります．
# そしてスカラーが丁度 $1$ の場合，ベクトルの長さが全く変わりません．

# %% [markdown]
# #### ベクトルの負の実数倍
#
# ベクトルに負の実数を掛けた例を示します．
# この図では，ベクトル${\bf v}$に対して，$-1$のスカラーを掛けています．
# このように，矢印が原点から反対方向に伸びていることが分かります．
#
# ![ベクトルの2倍](./images/scalar002.jpg)

# %% [markdown]
# *****
# ## ベクトルの加法
#
# ベクトルの加法について図解します．
# いま，ベクトル ${\bf a}$ とベクトル ${\bf b} $とのベクトル和 ${\bf a}+{\bf b} $は下図のようになります．
#
# ![ベクトル和1](./images/add001.jpg)

# %% [markdown]
# ベクトル和を幾何学的に求めるには，ベクトル ${\bf a}$ と ${\bf b}$ を含む平面を求めます．
# その平面上に ${\bf a}$ と ${\bf b}$ を辺とする平行四辺形を作図します．
# その平行四辺形において，原点と対頂点を結ぶ有向線分が ${\bf a}+{\bf b}$ となります．
# 上の図に平行四辺形を重ねてみます．
#
# ![ベクトル平行四辺形](./images/add002.jpg)
#
# この図は平面なので2次元に見えますが，実際には3次元であっても，さらにn次元であっても成立する方法です．
# 最初に ${\bf a}$ と ${\bf b}$ を含む平面を構成しますが，n次元空間においては超平面と呼ばれています．
# 一旦，超平面が設定されてしまえば，その上では2次元の感覚で作図することができます．

# %% [markdown]
# #### ベクトル加法の交換法則
#
# ベクトルの加法は<font color=blue>交換法則</font>が成り立ちます．
#
# > ${\bf a}+{\bf b} = {\bf b}+{\bf a}$
#
# このことを幾何学的に検証します．

# %% [markdown]
# まず，${\bf a}+{\bf b}$ですが，ベクトル${\bf a}$の終点からベクトル${\bf b}$を伸ばす処理になります．
#
# ![a+b](./images/add003.jpg)
#
# ${\bf b}+{\bf a}$は，ベクトル${\bf b}$の終点からベクトル${\bf a}$を伸ばす処理になります．
#
# ![b+a](./images/add004.jpg)
#
# このように，ベクトル和を作る手順に違いがありますが，ベクトルの和の場合は手順に依存せず同じ結果が得られます．

# %% [markdown]
# *****
# ## 線形部分空間
#
# ベクトル空間の線形部分空間は，それ自体がベクトル空間になっていますが，元のベクトル空間と部分空間あるいは部分空間どうしの関係を理解すると，ベクトル空間を操作する感覚が身に付きます．

# %% [markdown]
# ### 2次元実数ベクトル空間の部分空間
#
# 2次元実数ベクトル空間$\mathbb{R}^2$は，私達が良く知る平面と同一視できます．
# この2次元実数ベクトル空間の部分空間は3種類あります．
#
# | 部分空間 | 次元 | 特徴 |
# | :---: | :---: | :---: |
# | 零ベクトル空間 | 0 | 自明な部分空間 |
# | 1次元実数ベクトル空間 | 1 | 原点を通る任意の直線 |
# | 2次元実数ベクトル空間 | 2 | 自明な部分空間 |

# %% [markdown]
# 下図は，2次元実数ベクトル空間における1次元の線形部分空間の例を示しています．
# 図にあるように，どれも原点を通る直線になっています．
#
# ![1次元部分空間](./images/subspace001.jpg)

# %% [markdown]
# #### 1次元の部分空間の共通集合
#
# 2次元実数ベクトル空間の1次元線形部分空間は原点を通る直線になるので，もし2つの1次元線形部分空間${\bf W}_1$と${\bf W}_2$が一致していなければ，その共通部分${\bf W}_1{\cap}{\bf W}_2$は零ベクトル ${\bf 0}$ となります．

# %% [markdown]
# #### 1次元の部分空間の和集合
#
# 2次元実数ベクトル空間の1次元線形部分空間は原点を通る直線になるので，
# もし2つの1次元線形部分空間${\bf W}_1$と${\bf W}_2$が一致していなければ，その和集合${\bf W}_1+{\bf W}_2$は2次元実数ベクトル空間$\mathbb{R}^2$ と一致します．

# %% [markdown]
# ### 3次元実数ベクトル空間の部分空間
#
# 3次元実数ベクトル空間$\mathbb{R}^3$は，私達が良く知る空間と同一視できます．
# この3次元実数ベクトル空間の部分空間は4種類あります．
#
# | 部分空間 | 次元 | 特徴 |
# | :---: | :---: | :---: |
# | 零ベクトル空間 | 0 | 自明な部分空間 |
# | 1次元実数ベクトル空間 | 1 | 原点を通る任意の直線 |
# | 2次元実数ベクトル空間 | 2 | 原点を通る任意の平面 |
# | 3次元実数ベクトル空間 | 3 | 自明な部分空間 |

# %% [markdown]
# 1次元の線形部分空間は，前出の原点を通る直線と同様です．
# 2次元の線形部分空間は，原点を通る任意の平面となり，下図のようなイメージです．
#
# ![2次元部分空間](./images/subspace002.jpg)

# %% [markdown]
# #### 2次元の部分空間の共通集合
#
# 3次元実数ベクトル空間の2次元線形部分空間は原点を通る平面になるので，もし2つの2次元線形部分空間${\bf W}_1$と${\bf W}_2$が一致していなければ，その共通部分${\bf W}_1{\cap}{\bf W}_2$は原点を通る直線，すなわち，1次元線形部分空間となります．

# %% [markdown]
# #### 2次元部分空間と1次元の部分空間の和集合
#
# 3次元実数ベクトル空間の2次元線形部分空間${\bf W}$と，${\bf W}$に含まれない1次元線形部分空間${\bf V}$の和集合${\bf W}+{\bf V}$は3次元実数ベクトル空間$\mathbb{R}^3$ と一致します．

# %% [markdown]
# *****
# 数学の概念を全て図形で理解することは，論理的な間違えに気付けない危険性がありますが，初等段階においては感覚的に理解することは有効な手段となります．
